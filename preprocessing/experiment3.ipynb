# %%
import matplotlib.pyplot as plt
from crop_v1 import Cropper
import image_utils as itools
import cv2
import numpy as np
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
img_orange = itools.read_file("../dataset/5a/ST05_SE010112.jpg")
img_yellow = itools.read_file("../dataset/5a/ST05_SE031077.jpg")
img_yellow2 = itools.read_file("../dataset/5a/ST05_SE031098.jpg")
plt.imshow(np.hstack([img_orange, img_yellow, img_yellow2]))

# %%
contrast_orange = itools.contrast(img_orange)
contrast_yellow = itools.contrast(img_yellow)
contrast_yellow2 = itools.contrast(img_yellow2)
print(contrast_orange, contrast_yellow, contrast_yellow2)
# Out:
# 3.8626205793420483 1.9252776715329853 2.231004800787686

# %%
cropper = Cropper()
img = itools.rand_image("../dataset/5a")
cropped = cropper.crop(img)
contrast = itools.contrast(cropped)
print(contrast)
plt.imshow(cropped)
# Out:
# 15.075250681318646
