# %%
import matplotlib.pyplot as plt
from crop_v1 import Cropper
import cv2
import numpy as np
import image_utils as itools
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cropper = Cropper()
img = itools.read_file("../dataset/Petals Test/1B/ST1_SE010262.jpg")
plt.imshow(img)

# %%
gray = cropper.threshold(img)
plt.imshow(gray, cmap="gray")

# %%
contour = itools.find_largest_contour(gray)
image_contour = np.copy(img)
cv2.drawContours(image_contour, [contour], 0, (0, 255, 0), 2, cv2.LINE_AA, maxLevel=1)
plt.imshow(image_contour)

# %%
bbox = itools.bbox_contour(contour, 0)
print(bbox)
# Out:
# (576, -274, 1424, 1424)

# %%
cropper.process_dir("5a")
# Out:
# BBOX TOO CLOSE TO EDGE
# BBOX TOO CLOSE TO EDGE
# cropping 874 874
# cropping 609 609
# cropping 778 778
# cropping 590 590
# cropping 757 757
# cropping 757 757
# BBOX TOO CLOSE TO EDGE
# cropping 698 698
# BBOX TOO CLOSE TO EDGE
# cropping 459 459
# cropping 489 489
# cropping 568 568
# cropping 797 797
# cropping 603 603
# cropping 812 812
# cropping 599 599
# cropping 542 542
# BBOX TOO CLOSE TO EDGE
# cropping 561 561
# cropping 440 440
# cropping 568 568
# cropping 583 583
# cropping 771 771
# cropping 895 895
# BBOX TOO CLOSE TO EDGE
# cropping 954 954
# BBOX TOO CLOSE TO EDGE
# cropping 656 656
# cropping 901 901
# BBOX TOO CLOSE TO EDGE
# cropping 491 491
# cropping 545 545
# cropping 614 614
# cropping 681 681
# cropping 676 676
# cropping 1004 1004
# cropping 439 439
# cropping 598 598
# cropping 956 956
# cropping 684 684
# cropping 852 852
# cropping 1008 1008
# cropping 456 456
# cropping 745 745
# cropping 822 822
# BBOX TOO CLOSE TO EDGE
# BBOX TOO CLOSE TO EDGE
# ...
