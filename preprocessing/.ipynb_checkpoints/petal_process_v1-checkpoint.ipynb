# %%
import matplotlib.pyplot as plt
from petal_process_v1 import PetalProcessor
import cv2
import image_utils as itools
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
img = itools.read_file("../dataset/Petals Test/1B/ST1_SE010262.jpg")
plt.imshow(img)

# %%
processor = PetalProcessor("../dataset/Petals/")

# %%
# c_file = '../dataset/Petals Test/1A/ST02_SE031472.jpg'
# c_file = '../dataset/Petals Test/1B/ST1_SE010262.jpg'
c_file = '../dataset/Petals Test/1A/ST2_SE010217.jpg'
(c_img, c_gray, c_contour, c_bbox) = processor.update_bbox_boundaries(c_file)
plt.imshow(c_gray, cmap="gray")

# %%
processor.deduplicate()

# %%
smallest, largest = processor.find_extremes()
plt.imshow(smallest)
# Out:
# Smallest bbox: (1163, 2547, 2334, 2334) 5447556
# Largest bbox: (473, 426, 3246, 3246) 10536516
