# %%
import sys
import matplotlib.pyplot as plt
from process import Processor
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
processor = Processor()
img = processor.read_file("5a/ST05_SE010122.jpg")
plt.imshow(img)

# %%
mask = processor.mask(img)
plt.imshow(mask)

# %%
x,y,w,h = processor.bbox_crop_mask(mask)
print(x,y,w,h)
# Out:
# 345 665 735 735

# %%
masked_img = processor.apply_mask(img, mask)
plt.imshow(masked_img)

# %%
cropped_img = processor.crop(masked_img, x, y, w, h)
plt.imshow(cropped_img)
