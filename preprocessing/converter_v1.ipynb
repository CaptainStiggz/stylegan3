# %%
from convert_v1 import Converter
import matplotlib.pyplot as plt
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
converter = Converter()
img = converter.convert("/Volumes/My Passport for Mac/Original RAW Files/01_A_08242016/ST01_SE01/Capture/ST1_SE010261.NEF")
plt.imshow(img)
# Out:
# 0 / 0 completed.

# %%
converter.convert_dir("/Volumes/My Passport for Mac/Original RAW Files")
# Out:
# Converting files from /Volumes/My Passport for Mac/Original RAW Files (../dataset/originals)
# 2 files already converted.
# 95185 files to convert.
# 3 / 95187 completed.
# 4 / 95187 completed.
# 5 / 95187 completed.
# 6 / 95187 completed.
# 7 / 95187 completed.
# 8 / 95187 completed.
# 9 / 95187 completed.
# 10 / 95187 completed.
# 11 / 95187 completed.
# 12 / 95187 completed.
# 13 / 95187 completed.
# 14 / 95187 completed.
# 15 / 95187 completed.
# 16 / 95187 completed.
# 17 / 95187 completed.
# 18 / 95187 completed.
# 19 / 95187 completed.
# 20 / 95187 completed.
# 21 / 95187 completed.
# 22 / 95187 completed.
# 23 / 95187 completed.
# 24 / 95187 completed.
# 25 / 95187 completed.
# 26 / 95187 completed.
# 27 / 95187 completed.
# 28 / 95187 completed.
# 29 / 95187 completed.
# 30 / 95187 completed.
# 31 / 95187 completed.
# 32 / 95187 completed.
# 33 / 95187 completed.
# 34 / 95187 completed.
# 35 / 95187 completed.
# 36 / 95187 completed.
# 37 / 95187 completed.
# ...
